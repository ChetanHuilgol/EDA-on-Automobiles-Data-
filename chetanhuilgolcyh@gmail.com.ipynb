# %% [markdown]
# <p align="center"><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="260" height="110" /></p>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# 1. [**Introduction**](#Section1)<br>
# 2. [**Problem Statement**](#Section2)<br>
# 3. [**Installing & Importing Libraries**](#Section3)<br>
#   3.1 [**Installing Libraries**](#Section31)<br>
#   3.2 [**Upgrading Libraries**](#Section32)<br>
#   3.3 [**Importing Libraries**](#Section33)<br>
# 4. [**Data Acquisition & Description**](#Section4)<br>
# 5. [**Data Pre-Profiling**](#Section5)<br>
# 6. [**Data Pre-Processing**](#Section6)<br>
# 7. [**Data Post-Profiling**](#Section7)<br>
# 8. [**Exploratory Data Analysis**](#Section8)<br>
# 9. [**Summarization**](#Section9)</br>
#   9.1 [**Conclusion**](#Section91)</br>
#   9.2 [**Actionable Insights**](#Section91)</br>
#
# ---

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
#
# - Automobile industry is one of the most rapidly evolving in the world thanks to increasing demand for more fuel efficient and also high performance vehicles at the same time.
#
# - Recent development in the world, consciouness among people for air pollution and increasing deficiency of fossil fuel in the world has led companies to see future in hybrid vehicles(battery+fuel).
#
# - More and more advancement to manufacture battery powered vehicles may lead to EOP of fuel powered IC engines in the future. Future generation may never know the experience of driving good old IC engine cars....

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
#   - Automobile industry has strong growth rate due to rise in middle class income and young population.
#
#   - The auto industry is the single greatest engine of economic growth in the world. The global auto industry is a key sector of the economy for every major country in the world. The industry continues to grow, registering a 30 percent increase over the past decade.
#
#   - Cars are one of the world's largest export products, surpassing oil revenues, for example, world car exports by country in 2016 estimated at 698.2 billion dollars. USA.
#
#   - Most common challenges faced by automobile companies over the world as on today.
#     -Outbreak of COVID-19.
#     -Evolution of Connected Vehicles and Growing Prominence of Autonomous Vehicle.
#     -Modification in Powertrain and Increasing Demand for Electric Vehicles.
#     -Modifications in Supply Chain and Business Model.
#     -Increasing Y-o-Y Unsold Inventory.
#
#   - Three major structural challenges: The semiconductor crisis, trade tensions, relocation, rising raw material costs, transportation costs make it difficult for companies to meet with economical requirements of the customer.
#
#   - Derive a scenario with the insights including price and efficiency to help the companies to focus on, to attract more buyers.

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - This section is emphasised on installing and importing the necessary libraries that will be required.

# %% [markdown]
# ### **Installing Libraries**

# %%
# !pip install -q datascience                                         # Package that is required by pandas profiling
# !pip install -q pandas-profiling                                    # Library to generate basic statistics about data

# %%
# !pip install -q --upgrade pandas-profiling                          # Upgrading pandas profiling to the latest version

# %% [markdown]
# ### **Importing Libraries**

# %%
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
from pandas_profiling import ProfileReport                          # Import Pandas Profiling (To generate Univariate Analysis)
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                               # Importing seaborn library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import scipy as sp                                                  # Importing library for scientific calculations

# %% [markdown]
# **DATA ACQUISITION**

# %%
data = pd.read_csv(filepath_or_buffer = 'https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/Automobile_data.csv')
print('Data Shape:', data.shape)
data.head()
# Out:
# Data Shape: (205, 26)
#    symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3                 ?  alfa-romero  ...       21          27  13495
# 1          3                 ?  alfa-romero  ...       21          27  16500
# 2          1                 ?  alfa-romero  ...       19          26  16500
# 3          2               164         audi  ...       24          30  13950
# 4          2               164         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ### **Data Description**
#
# - To get some quick description out of the data you can use describe method defined in pandas library.

# %%
data.describe()
# Out:
#         symboling  wheel-base  ...    city-mpg  highway-mpg
# count  205.000000  205.000000  ...  205.000000   205.000000
# mean     0.834146   98.756585  ...   25.219512    30.751220
# std      1.245307    6.021776  ...    6.542142     6.886443
# min     -2.000000   86.600000  ...   13.000000    16.000000
# 25%      0.000000   94.500000  ...   19.000000    25.000000
# 50%      1.000000   97.000000  ...   24.000000    30.000000
# 75%      2.000000  102.400000  ...   30.000000    34.000000
# max      3.000000  120.900000  ...   49.000000    54.000000
#
# [8 rows x 10 columns]

# %% [markdown]
# **Observations:**
#
#
# *   Symboling data column has a minimum value of -2
# *   Normalised losses and price are not included, hence these have mixed datatypes.
#
# *   wheel base,length,width and height are in inches
# *   Curbweight in pounds and engine size in cc.

# %% [markdown]
# ### **Data Information**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data.
#
# - We need to perform pandas profiling and get some observations out of it...

# %%
 profile = ProfileReport(df=data)
 profile.to_file(output_file='Pre Profiling Report.html')
 print('Accomplished!')

from google.colab import files
files.download('Pre Profiling Report.html')

# %% [markdown]
#  **Observations**
#
# 1.   There is no missing data in the dataset.
#
# 2.   There is no redundant data
#
# 3.   Total number of observations for each column is 205
#
# 4.   There are 26 different aspects of a vehicle for which data is recorded, in which 10 are numerical and 16 are categorical.
#
# 5.   Price ia uniformly distributed over the dataset.
#
# 6.   Symboling data has 67 zeroes.
#
# 7.   normalised losses,bore,stroke,horsepower,peak-rpm and price columns have inconsistent data as the data type is object where as it should be int or float.

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---
# -From profiling report we inferred that there is no missing or redundant data.
#
# We need to do following data handling processes.
#
#   - Handling inconsistent data,[normalised losses,bore,stroke,horsepower,peak-rpm and price]
#
#   - Handling outliers,
#
#   - Handling typos

# %%
df1=data.copy()
df1['normalized-losses'].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
df1['normalized-losses'].replace('?',int(0),inplace=True)
df1['normalized-losses'].replace(0,df1['normalized-losses'].median(),inplace=True)

# %%
df1['normalized-losses']=df1['normalized-losses'].apply(pd.to_numeric)
df1['normalized-losses'].dtype
df1['normalized-losses'].describe()
# Out:
# count    205.00000
# mean     118.20000
# std       32.58419
# min       65.00000
# 25%      101.00000
# 50%      103.00000
# 75%      137.00000
# max      256.00000
# Name: normalized-losses, dtype: float64

# %%
df1['bore'].unique()
# Out:
# array(['3.47', '2.68', '3.19', '3.13', '3.5', '3.31', '3.62', '2.91',
#        '3.03', '2.97', '3.34', '3.6', '2.92', '3.15', '3.43', '3.63',
#        '3.54', '3.08', '?', '3.39', '3.76', '3.58', '3.46', '3.8', '3.78',
#        '3.17', '3.35', '3.59', '2.99', '3.33', '3.7', '3.61', '3.94',
#        '3.74', '2.54', '3.05', '3.27', '3.24', '3.01'], dtype=object)

# %%
df1['bore'].replace('?',int(0),inplace=True)
df1['bore'].replace(0,df1['bore'].median(),inplace=True)
df1['bore'].describe()
# Out:
# count      205
# unique      39
# top       3.62
# freq        23
# Name: bore, dtype: object

# %%
df1['bore']=df1['bore'].apply(pd.to_numeric)
df1['bore'].dtype
df1['bore'].describe()
# Out:
# count    205.000000
# mean       3.329366
# std        0.270858
# min        2.540000
# 25%        3.150000
# 50%        3.310000
# 75%        3.580000
# max        3.940000
# Name: bore, dtype: float64

# %%
df1['stroke'].unique()
# Out:
# array(['2.68', '3.47', '3.4', '2.8', '3.19', '3.39', '3.03', '3.11',
#        '3.23', '3.46', '3.9', '3.41', '3.07', '3.58', '4.17', '2.76',
#        '3.15', '?', '3.16', '3.64', '3.1', '3.35', '3.12', '3.86', '3.29',
#        '3.27', '3.52', '2.19', '3.21', '2.9', '2.07', '2.36', '2.64',
#        '3.08', '3.5', '3.54', '2.87'], dtype=object)

# %%
df1['stroke'].replace('?',int(0),inplace=True)
df1['stroke'].replace(0,df1['stroke'].median(),inplace=True)
df1['stroke'].unique()
# Out:
# array(['2.68', '3.47', '3.4', '2.8', '3.19', '3.39', '3.03', '3.11',
#        '3.23', '3.46', '3.9', '3.41', '3.07', '3.58', '4.17', '2.76',
#        '3.15', 3.29, '3.16', '3.64', '3.1', '3.35', '3.12', '3.86',
#        '3.29', '3.27', '3.52', '2.19', '3.21', '2.9', '2.07', '2.36',
#        '2.64', '3.08', '3.5', '3.54', '2.87'], dtype=object)

# %%
df1['stroke']=df1['stroke'].apply(pd.to_numeric)
df1['stroke'].dtype
df1['stroke'].describe()
# Out:
# count    205.000000
# mean       3.256098
# std        0.313634
# min        2.070000
# 25%        3.110000
# 50%        3.290000
# 75%        3.410000
# max        4.170000
# Name: stroke, dtype: float64

# %%
df1['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', '?', '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
df1['horsepower'].replace('?',int(0),inplace=True)
df1['horsepower'].replace(0,df1['horsepower'].median(),inplace=True)
df1['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', 95.0, '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
df1['horsepower']=df1['horsepower'].apply(pd.to_numeric)
df1['horsepower'].dtype
df1['horsepower'].describe()
# Out:
# count    205.000000
# mean     104.165854
# std       39.529733
# min       48.000000
# 25%       70.000000
# 50%       95.000000
# 75%      116.000000
# max      288.000000
# Name: horsepower, dtype: float64

# %%
df1['peak-rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', '?', '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
df1['peak-rpm'].replace('?',0,inplace=True)
df1['peak-rpm'].replace(0,df1['peak-rpm'].median(),inplace=True)
df1['peak-rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', 5200.0, '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
df1['peak-rpm']=df1['peak-rpm'].apply(pd.to_numeric)
df1['peak-rpm'].dtype
df1['peak-rpm'].describe()
# Out:
# count     205.000000
# mean     5126.097561
# std       477.035772
# min      4150.000000
# 25%      4800.000000
# 50%      5200.000000
# 75%      5500.000000
# max      6600.000000
# Name: peak-rpm, dtype: float64

# %%
df1['price'].unique()
# Out:
# array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#        '23875', '?', '16430', '16925', '20970', '21105', '24565', '30760',
#        '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#        '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#        '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#        '12945', '10345', '6785', '11048', '32250', '35550', '36000',
#        '5195', '6095', '6795', '6695', '7395', '10945', '11845', '13645',
#        '15645', '8495', '10595', '10245', '10795', '11245', '18280',
#        '18344', '25552', '28248', '28176', '31600', '34184', '35056',
#        '40960', '45400', '16503', '5389', '6189', '6669', '7689', '9959',
#        '8499', '12629', '14869', '14489', '6989', '8189', '9279', '5499',
#        '7099', '6649', '6849', '7349', '7299', '7799', '7499', '7999',
#        '8249', '8949', '9549', '13499', '14399', '17199', '19699',
# ...

# %%
df1['price'].replace('?',0,inplace=True)
df1['price'].replace(0,df1['price'].median(),inplace=True)
df1['price'].unique()
# Out:
# array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#        '23875', 10198.0, '16430', '16925', '20970', '21105', '24565',
#        '30760', '41315', '36880', '5151', '6295', '6575', '5572', '6377',
#        '7957', '6229', '6692', '7609', '8558', '8921', '12964', '6479',
#        '6855', '5399', '6529', '7129', '7295', '7895', '9095', '8845',
#        '10295', '12945', '10345', '6785', '11048', '32250', '35550',
#        '36000', '5195', '6095', '6795', '6695', '7395', '10945', '11845',
#        '13645', '15645', '8495', '10595', '10245', '10795', '11245',
#        '18280', '18344', '25552', '28248', '28176', '31600', '34184',
#        '35056', '40960', '45400', '16503', '5389', '6189', '6669', '7689',
#        '9959', '8499', '12629', '14869', '14489', '6989', '8189', '9279',
#        '5499', '7099', '6649', '6849', '7349', '7299', '7799', '7499',
#        '7999', '8249', '8949', '9549', '13499', '14399', '17199', '19699',
# ...

# %%
df1['price']=df1['price'].apply(pd.to_numeric)
df1['price'].dtype
df1['price'].describe()
# Out:
# count      205.000000
# mean     13148.414634
# std       7879.822024
# min       5118.000000
# 25%       7788.000000
# 50%      10198.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
df1.columns.unique()
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df1['num-of-doors'].replace('?',0,inplace=True)
df1['num-of-doors'].replace(0,'four',inplace=True)
df1['num-of-doors'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---

# %%
 profile = ProfileReport(df=df1)
 profile.to_file(output_file='Pre Profiling Report.html')
 print('Accomplished!')

from google.colab import files
files.download('Pre Profiling Report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Accomplished!

# %% [markdown]
# Data set is corrected of inconsistent data and duplicate rows are cleared as well.

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# ---

# %% [markdown]
# **-  Univariate analysis**

# %%
df1.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
feature=['fuel-type','aspiration',
       'num-of-doors', 'body-style', 'drive-wheels', 'engine-location','engine-type',
       'num-of-cylinders', 'engine-size', 'fuel-system','make','normalized-losses']

# %%
feature_1=['symboling', 'normalized-losses','wheel-base', 'length', 'width', 'height', 'curb-weight','engine-size', 'bore', 'stroke',
       'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg','highway-mpg', 'price']

# %%
list(enumerate(feature))
# Out:
# [(0, 'fuel-type'),
#  (1, 'aspiration'),
#  (2, 'num-of-doors'),
#  (3, 'body-style'),
#  (4, 'drive-wheels'),
#  (5, 'engine-location'),
#  (6, 'engine-type'),
#  (7, 'num-of-cylinders'),
#  (8, 'engine-size'),
#  (9, 'fuel-system'),
#  (10, 'make'),
#  (11, 'normalized-losses')]

# %%
list(enumerate(feature_1))
# Out:
# [(0, 'symboling'),
#  (1, 'normalized-losses'),
#  (2, 'wheel-base'),
#  (3, 'length'),
#  (4, 'width'),
#  (5, 'height'),
#  (6, 'curb-weight'),
#  (7, 'engine-size'),
#  (8, 'bore'),
#  (9, 'stroke'),
#  (10, 'compression-ratio'),
#  (11, 'horsepower'),
#  (12, 'peak-rpm'),
#  (13, 'city-mpg'),
#  (14, 'highway-mpg'),
#  (15, 'price')]

# %%
plt.figure(figsize=(30,40))
for i in enumerate(feature):
  plt.subplot(6,2,i[0]+1)
  sns.countplot(x=i[1],data=df1)
  plt.xticks(rotation=45)

# %%
plt.figure(figsize=(20,20))
for i in enumerate(feature_1):
  plt.subplot(4,4,i[0]+1)
  sns.histplot(x=i[1],data=df1)
  plt.xticks(rotation=45)

# %% [markdown]
# # **Bivariate analysis**

# %%
plt.figure(figsize=(30,40))
for i in enumerate(feature):
  plt.subplot(6,2,i[0]+1)
  sns.barplot(y=df1['price'],x=i[1],data=df1)
  plt.xticks(rotation=45)

# %%
plt.figure(figsize=(30,40))
sns.set(font_scale=1)
for i in enumerate(feature):
  plt.subplot(6,2,i[0]+1)
  sns.barplot(y=df1['city-mpg'],x=i[1],data=df1)
  plt.xticks(rotation=45)

# %%
x=['price','city-mpg',
 'highway-mpg','horsepower']

# %%
plt.figure(figsize=[15,8])
sns.pairplot(df1,x_vars=x,y_vars=x)

# %%
x_vars=['curb-weight','width','length','wheel-base','engine-size','height']
y_vars=['price']
sns.pairplot(df1,x_vars=x_vars,y_vars=y_vars)

# %%
x_vars=['curb-weight','width','length','wheel-base','engine-size','height']
y_vars=['city-mpg','highway-mpg']
sns.pairplot(df1,x_vars=x_vars,y_vars=y_vars)

# %% [markdown]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---

# %% [markdown]
# <a name = Section91></a>
#
# ### **9.1 Conclusion**
#
# # - Inferences from Univariate analysis of dataset:
#
# 1.   Toyota has the highest number of cars overall, followed by nissan and mazda.
# 2.   Gas is seen as a more common fuel than diesel.
#
# 3.   Standard aspiration and four doors are more common compared to turbo aspiration and two doors.
#
# 4.   Body style sedan is the highest followed by hatchbacks and the least among the group are convertibles.
#
# 5.   Fwd drive wheels are more common than the other(rwd,4wd).
#
# 6.   Front engine location is found more than rear location which is very less compared to the former.
# 7.   Engine type ohc with four cylinders are found more than the other types.
#
# 8.   Engine size are concentrated more between 90 and 110 cc and maximum at 122cc and as we go even higher the concentration reduces.
#
# 9.   Fuel system 'mpfi' is found more than other systems followed by '2bbl'.
#
# 10.  Curbweight is found largely between 1500 and 3000 pounds.
#
# 11.  Wheel base is largely between 92 and 105 inches.
#
# 12.  Horsepower is found more concentrated between 60 and 120, and peak rpm between 4500 and 5000 rpm.
#
# 13.  City-mpg is 25 for most cars followed by 20 mpg and 35 mpg where as highway-mpg is 30 for most cars followed by 40,35 and 25 for second most number of cars.
# 14.  Price range lies between 0 and 20000$ for most cars.
#
#
#
#
#
#
#
#
#
# -

# %% [markdown]
# # Inferences from Bivariate analysis:
#
# 1.   Price and horsepower are directly proportional to each other where as city and highway mpg are inversely proportional to both price and horsepower.
#
# 1.   Gas-fuelled cars are lesser in price where as diesel fuelled cars have more price and more mileage than the former.
#
# 1.   Standard aspiration cars are less in price compared to turbo and also standard aspiration cars tend to provide more mileage.
#
# 1.   Hatchback and sedan body styles are lesser in price compared to other styles and also provide more mileage than other body styles.
#
# 1.   Forward Drive wheels are less in price and tend to provide more mileage compared to other drive wheels.
#
# 1.   Front located engine cars have lesser price compared to rear location and also tend to give more mileage.
#
# 1.   Engine type 'dohcv' is costlier where as 'ohc' an 'l' are least pricey comparatively and also provide more city and highway mpg.
#
# 1.   Twelve cylinder engine cars are more costly followed by eight and six cylinder engines.Three cylinder engine cars are the least pricey and provide more mileage as well.
#
# 1.   As engine size increases, price increase and city and highway mpg decreases.
#
# 1.   Fuel system 'mpfi' and 'idi'are more costly where as '2bbl' and '1bbl' are least pricey and provide more mileage comparatively.
#
# 1.   Increase in curb weight and engine size reduces city and highway mpg and at the same time results in increase in horsepower of the car.
#
# 1.   BMW,Mercedes Benz,Jaguar,Porsche and volvo cars are considerable costlier than other makes and chevrolet cars are the least pricey compared to other makes.

# %% [markdown]
# <a name = Section92></a>
# ### **9.2 Actionable Insights**
#
# ### Considering price and mileage of the car following insights would be helpful:
#
#
#
# 1.   Price is directly related to horsepower which is inversely related to city and highway mpg, hence horsepower of the car to be limited well within the price range required.
#
# 1.   Price is inversely related to hatchback and sedan body styles,standard aspiration, fwd drive wheels,front engine location,'ohc' and 'l' engine type and three cylinder engines which in turn are directly related to city and highway mpg. Increasing the number in these aspects will reduce the price and increase the mileage as well considerably.
#
# 1.   Price is directly related turbo aspiration,hardtop and convertible body styles,rwd drive wheels,rear engine location,dohcv engine type,twelve,eight and six cylinder engines, and mpfi and idi fuel systems which in turn are inversely related to city and highway mpg. Reduce or avoid these aspects in order to gain more on the mpg and reduce the price.
#
# 2.   Price is directly related to diesel fuel type which also is directly related to city and highway mpg so, it is best if this fuel type is kept optimum. Either try and work on reducing the price of diesel fuel type or increase the fuel economy of gas fuel.
